# %% [markdown]
# # Anexo 5: Propuesta Original - Preentrega 1

# %% [markdown]
# ## Introducción
# Este anexo contiene la propuesta original presentada en la Preentrega 1 del proyecto **Diccionario Mágico para Atrevidos**. Incluye el desarrollo conceptual inicial y el código asociado en su estado original.

# %% [raw]
# Título: Diccionario Mágico para Atrevidos
#
# Autor: Rocío Dopazo
# Curso: Generación de Prompts
# N° de Comisión: [67115]
# Fecha: 19/11/2024

# %%
1.Presentación del Problema 
1.1 Problema Elegido: 
Las personas a menudo enfrentan dificultades para comprender conceptos complejos debido a explicaciones abstractas o técnicas que no están adaptadas a diferentes niveles de entendimiento, o se encuentran muy alejados de las experiencias cotidianas.Esto no sólo genera confusión, sino que también afecta nuestra capacidad para comunicarnos de manera efectiva. Por si fuera poco, muchas de las  palabras  que utilizamos para describir estos conceptos tienen raíces etimológicas que las asocian a emociones negativas o limitantes, lo que refuerza una percepción confusa o poco constructiva.
El lenguaje no sólo transmite información, sino que también influye en cómo percibimos y enfrentamos los conceptos que define. El desconocimiento de la “energía” de las palabras que utilizamos a diario, pueden perpetuar connotaciones y resultados  que no se condicen con lo deseado Sin herramientas que desglosen estos temas de manera creativa y accesible, el aprendizaje se vuelve un desafío, y la comunicación pierde claridad e impacto.

1.2 Justificación
Accesibilidad al conocimiento:
Los conceptos complejos suelen explicarse de manera técnica, alejándolos de la comprensión cotidiana.
La falta de herramientas que simplifiquen estas explicaciones crea barreras para el aprendizaje efectivo.
Impacto emocional del lenguaje:
Muchas palabras tienen asociaciones negativas o limitantes en su origen etimológico, afectando la forma en que nos relacionamos con las ideas y las emociones que describen.
Necesidad de explicaciones creativas:
Sin un enfoque que combine creatividad con claridad, los conceptos complejos pueden parecer inaccesibles o desalentadores.
Una explicación creativa no solo facilita el aprendizaje, sino que también lo transforma en una experiencia más atractiva y memorable.
Este problema afecta tanto la comprensión individual como la capacidad de comunicarse de manera efectiva y consciente.
    
2. Desarrollo de la Propuesta de Solución
2.1 Descripción del Proyecto:
El Diccionario Mágico para Atrevidos es un asistente que engloba (tres objetivos):
Explica conceptos complejos desde su raíz etimológica:
Proporciona un desglose histórico y cultural de palabras clave, facilitando la comprensión profunda y creativa de temas abstractos.
Evalúa la energía de las palabras:
Clasifica las palabras en tres niveles según las emociones asociadas en su origen:
Baja vibración: Asociada a emociones negativas o limitantes.
Media vibración: Asociada a emociones neutras o prácticas.
Alta vibración: Asociada a emociones positivas, apertura o expansión.
Proporciona alternativas constructivas:
Sugiere palabras de alta vibración como opciones más alineadas con emociones positivas o expansivas.
Genera visualizaciones mágicas:
Representa visualmente las palabras y sus conceptos para reforzar el aprendizaje de manera creativa y accesible.
    
2.2 Ejemplo de Uso del DMA 
Concepto Complejo: Gravedad
Explicación etimológica:
"'Gravedad' proviene del latín 'gravitas,' que significa 'peso' o 'seriedad.' Describe la fuerza que mantiene todo conectado, como si el universo tejiera hilos invisibles."
Evaluación energética:
"Vibración media: es un término neutro asociado a la conexión y el peso, tanto físico como simbólico."
Propuesta de alta vibración:
"Si se busca una asociación más expansiva, puede usarse 'atracción universal' para resaltar la conexión entre los cuerpos celestes y la energía que los une."
Palabra: Trabajo
Explicación etimológica:
"'Trabajo' proviene del latín 'tripalium,' un instrumento de tortura, lo que lo asocia con sufrimiento y esfuerzo forzado."
Evaluación energética:
"Baja vibración: debido a su asociación con sufrimiento y esfuerzo doloroso."
Propuesta de alta vibración:
'Actividad' o 'proyecto' son términos más alineados con una percepción positiva y creativa del esfuerzo."

3. Modelos de IA a utilizar
3.1 Texto-Texto (GPT-4):
Generará explicaciones etimológicas detalladas.
Simplificará conceptos complejos de manera creativa y adaptada al usuario.
Evaluará la energía de las palabras según sus asociaciones históricas y culturales.
Proporcionará alternativas lingüísticas alineadas con emociones positivas.

3.2Texto-Imagen (DALL·E):
Creará visualizaciones mágicas que representen tanto conceptos complejos como la energía de las palabras.
Ejemplo: "Representa la palabra 'reto' como un camino iluminado lleno de desafíos emocionantes."

4. Viabilidad: Limitaciones y Soluciones:

4.1 Vialidad
Aspectos Técnicos:
GPT-4: Lo evalue con el mismo chat y me recomendó está versión dado que es 
-Ideal para generar explicaciones detalladas y creativas de conceptos complejos
- Tambien puede evaluar el impacto emocional del lenguaje.
 Asimismo DALL·E resulta perfecto para generar imágenes atractivas y conceptuales que refuercen el entendimiento.
 
4.2 Limitaciones y soluciones 
-Resultados visuales (DALL·E):
Algunas imágenes pueden necesitar ajustes iterativos en los prompts para lograr representaciones precisas.
-Complejidad de términos:
Para palabras con múltiples significados, se priorizarán las más comunes o relevantes.

5. Impacto del Proyecto
El DICCIONARIO MÁGICO PARA ATREVIDOS es innovador y cuenta con triple inpacto positivo:
a)Educativo:
Facilita el aprendizaje de conceptos complejos desde un enfoque creativo y cultural.
b)Transformador:
Promueve elecciones lingüísticas conscientes, alineadas con las intenciones y emociones del usuario.
c)Visual:
Refuerza la comprensión a través de representaciones gráficas mágicas y atractivas.

6. Evaluacion del progreso y Conclusión
En el proceso de desarrollo me encontre con que tuve que realizar muchas interacciones y recurrir a fuentes para optimizar el código.
Experimente problemas en cuenta a la creación de las imágenes , pero creo que pude resolverlos. 
Tambien tuve que ir iterando y modificando la estructura de la parte de la explicación dado que los maximos o mínimos me permitian obtener el resultado buscado, fui resolviendo alguns cosas pero otras aún me quedan por probar.
Me gustaria darle alguna interfaz y hacerla más amigable , y optimizar errores en el código ( lo cambie mil veces y esta es la versión que quedo hasta el momento.

7. Ejecución
La ejecución se pensó sensilla y en un solo request o consulta para optimizar incluso el uso de tokens 
Consiste de : Mensaje de bienvenida, pregunta al usuario que palabra quiere elegir mediante el ingreso de datos externos, respuesta y devuelve una imagen asociada a la palabra ingresada.
En ocasiones me da error 500, pero consulte y aparentemente no se debe al código. 

El objetivo del DICCIONARIO MÁGICO PARA ATREVIDOS ES QUE LA PERSONA PUEDA CONSULTAR, OBTENER UNA RESPUESTA SIMPLE PERO COMPLETA , REFLEXIONAR ACERCA DEL CONCEPTO Y CONOCER LA ENERGÍA ASOCIADO A CADA UNO DE ELLOS, PARA LUEGO ELEGIR ALTERNATIVAS , O AL MENOS SER MÁS COSNCIENTE DEL USO DE SUS PALABRAS.

# %%
1° Código para EL DICCIONARIO MAGICO PARA ATREVIDOS (DIMA) con GPT4 Y DALL.E

# %%
# Importar la biblioteca OpenAI
import openai

# Configurar la clave API
openai.api_key = "AQUI"  # Reemplaza con tu clave API válida

# Mostrar mensaje de bienvenida
print("🌠 Bienvenido al Diccionario Mágico para Atrevidos 🌠")
print("✨ Aquí puedes invocar palabras para descubrir su esencia oculta, su energía y alternativas mágicas. ✨")

# Pedir al usuario que ingrese una palabra
palabra = input("🔮 ¿Qué palabra deseas invocar para conocer su esencia oculta? Escribe tu palabra aquí: ").strip().lower()

# Crear el prompt mágico para el análisis textual
concept_prompt = f"""
Analiza la palabra '{palabra}' con base en los siguientes criterios:
1. **Etimología**: Describe el origen histórico de la palabra de manera breve pero completa.
2. **Energía**: Clasifica su energía como baja, media o alta, según estos criterios:
   - Baja vibración: Asociada con miedo, inseguridad, sufrimiento o connotaciones negativas.
   - Media vibración: Conceptos neutros o prácticos, sin emociones extremas.
   - Alta vibración: Asociada con emociones positivas, entusiasmo o propósito elevado.
   Proporciona una breve explicación de por qué tiene esa clasificación.
3. **Alternativas mágicas**: Sugiere tres palabras alternativas con connotaciones más positivas o vibraciones altas. Explica brevemente cada una.
"""

try:
    # Solicitar la respuesta textual al modelo GPT-4
    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": "Eres un asistente mágico que evalúa palabras de manera estructurada: etimología, energía y alternativas, según criterios de vibración energética."},
            {"role": "user", "content": concept_prompt}
        ],
        max_tokens=300,  # Ajustado para permitir respuestas completas
        temperature=0.7
    )
    
    # Procesar la respuesta textual
    respuesta = response['choices'][0]['message']['content']
    
    # Dividir y validar cada sección
    try:
        etimologia = respuesta.split("2. **Energía**:")[0].strip()
        energia = respuesta.split("2. **Energía**:")[1].split("3. **Alternativas mágicas**:")[0].strip()
        alternativas = respuesta.split("3. **Alternativas mágicas**:")[1].strip()
    except IndexError:
        etimologia = "No se encontró información sobre la etimología."
        energia = "No se encontró información sobre la energía."
        alternativas = "No se encontraron alternativas mágicas."

    # Mostrar el análisis textual
    print("\n🔮 Aquí tienes el significado mágico de tu palabra:\n")
    print("1. **Etimología**:")
    print(etimologia)
    print("\n2. **Energía**:")
    print(energia)
    print("\n3. **Alternativas mágicas y sus significados**:")
    print(alternativas)
    
    # Crear un prompt para la generación de imágenes basado en la etimología y energía
    image_prompt = f"""
    A magical and artistic representation of the word '{palabra}', inspired by:
    - Etimología: {etimologia.strip()}
    - Energía: {energia.strip()}
    Use vibrant colors, fantasy elements, and mystical designs to visually represent its essence.
    """
    
    # Limitar la longitud del prompt de la imagen a 1000 caracteres
    if len(image_prompt) > 1000:
        image_prompt = image_prompt[:1000]

    # Solicitar una imagen al modelo DALL·E
    try:
        image_response = openai.Image.create(
            prompt=image_prompt,
            n=1,
            size="512x512"
        )
        # Obtener la URL de la imagen generada
        image_url = image_response['data'][0]['url']
        print("\n🖼️ Aquí tienes una representación visual mágica de tu palabra:\n")
        print(image_url)
    except Exception as img_error:
        print("\n⚠️ No se pudo generar la imagen. Detalles del error:")
        print(str(img_error))

except Exception as e:
    print("\n⚠️ Hubo un error al procesar tu solicitud. Por favor, verifica tu conexión o clave API.")
    print(str(e))
# Out:
# 🌠 Bienvenido al Diccionario Mágico para Atrevidos 🌠
# ✨ Aquí puedes invocar palabras para descubrir su esencia oculta, su energía y alternativas mágicas. ✨
# 🔮 ¿Qué palabra deseas invocar para conocer su esencia oculta? Escribe tu palabra aquí:  "No se"
# 🔮 Aquí tienes el significado mágico de tu palabra:
#
# 1. **Etimología**:
# 1. **Etimología**: "No se" es una combinación de dos palabras en español. "No" proviene del latín "non", que se usa para negar o rechazar algo. "Se" es un pronombre reflexivo y viene del latín "se", que se usa para referirse al sujeto de la oración en una manera indirecta. En conjunto, "no se" se utiliza normalmente para expresar incertidumbre o desconocimiento sobre algo.
#
# 2. **Energía**:
# "No se" tiene una energía de vibración baja. Esta clasificación se debe a que a menudo se utiliza para expresar desconocimiento, duda, inseguridad o indecisión, emociones que están asociadas con la inseguridad o el miedo a lo desconocido.
#
# ...
